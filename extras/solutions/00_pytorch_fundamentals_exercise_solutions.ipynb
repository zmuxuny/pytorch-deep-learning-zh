# %% [markdown]
# # 00. PyTorch 基础练习参考解答
#
# ### 1. 阅读文档
#
# 学习深度学习（以及编程本身）很重要的一环，是熟悉你正在使用框架的官方文档。课程后续会频繁使用 PyTorch 文档，所以建议先花 10 分钟阅读以下内容（暂时看不懂也没关系，当前重点是建立认知）：
#   * [`torch.Tensor` 文档](https://pytorch.org/docs/stable/tensors.html#torch-tensor)。
#   * [`torch.cuda` 文档](https://pytorch.org/docs/master/notes/cuda.html#cuda-semantics)。

# %%
# 本题无需代码（文档阅读）

# %% [markdown]
# ### 2. 创建一个形状为 `(7, 7)` 的随机张量。

# %%
# 导入 torch
import torch 

# 创建随机张量
X = torch.rand(size=(7, 7))
X, X.shape
# Out:
# (tensor([[0.5656, 0.4012, 0.1987, 0.2464, 0.6861, 0.4953, 0.3433],
#          [0.0032, 0.0228, 0.9020, 0.1267, 0.8009, 0.5274, 0.7453],
#          [0.9123, 0.8138, 0.1667, 0.5998, 0.4657, 0.4473, 0.8367],
#          [0.5302, 0.2213, 0.4747, 0.6485, 0.4770, 0.8675, 0.3054],
#          [0.4226, 0.1398, 0.4495, 0.6974, 0.1808, 0.5872, 0.6931],
#          [0.2153, 0.7517, 0.3505, 0.3815, 0.3244, 0.2511, 0.4269],
#          [0.1158, 0.6696, 0.3733, 0.2633, 0.4102, 0.1101, 0.1613]]),
#  torch.Size([7, 7]))

# %% [markdown]
# ### 3. 使用第 2 题中的张量，与另一个形状为 `(1, 7)` 的随机张量做矩阵乘法（提示：你可能需要转置第二个张量）。

# %%
# 再创建一个随机张量
Y = torch.rand(size=(1, 7))
# Z = torch.matmul(X, Y) # 形状不匹配会报错
Z = torch.matmul(X, Y.T) # 转置后可正常运行
Z, Z.shape
# Out:
# (tensor([[1.0888],
#          [1.7506],
#          [1.8468],
#          [1.7496],
#          [1.9022],
#          [1.2684],
#          [0.8617]]), torch.Size([7, 1]))

# %% [markdown]
# ### 4. 将随机种子设置为 `0`，然后重新完成第 2 和第 3 题。
#
# 输出应为：
# ```
# (tensor([[1.8542],
#          [1.9611],
#          [2.2884],
#          [3.0481],
#          [1.7067],
#          [2.5290],
#          [1.7989]]), torch.Size([7, 1]))
# ```

# %%
# 设置手动随机种子
torch.manual_seed(0)

# 创建两个随机张量
X = torch.rand(size=(7, 7))
Y = torch.rand(size=(1, 7))

# 矩阵乘法
Z = torch.matmul(X, Y.T)
Z, Z.shape
# Out:
# (tensor([[1.8542],
#          [1.9611],
#          [2.2884],
#          [3.0481],
#          [1.7067],
#          [2.5290],
#          [1.7989]]), torch.Size([7, 1]))

# %% [markdown]
# ### 5. 说到随机种子，我们已经看到如何用 `torch.manual_seed()` 设置它。那么 GPU 上有对应方法吗？（提示：需要查看 `torch.cuda` 文档）
#   * 如果有，把 GPU 的随机种子设置为 `1234`。

# %%
# 在 GPU 上设置随机种子
torch.cuda.manual_seed(1234)

# %% [markdown]
# ### 6. 创建两个形状为 `(2, 3)` 的随机张量，并都发送到 GPU（本题需要可用 GPU）。创建张量时设置 `torch.manual_seed(1234)`（不必是 GPU 专用随机种子）。输出应类似：
#
# ```
# Device: cuda
# (tensor([[0.0290, 0.4019, 0.2598],
#          [0.3666, 0.0583, 0.7006]], device='cuda:0'),
#  tensor([[0.0518, 0.4681, 0.6738],
#          [0.3315, 0.7837, 0.5631]], device='cuda:0'))
# ```

# %%
# 设置随机种子
torch.manual_seed(1234)

# 检查是否可用 GPU
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")

# 在 GPU 上创建两个随机张量
tensor_A = torch.rand(size=(2,3)).to(device)
tensor_B = torch.rand(size=(2,3)).to(device)
tensor_A, tensor_B
# Out:
# Device: cuda
# (tensor([[0.0290, 0.4019, 0.2598],
#          [0.3666, 0.0583, 0.7006]], device='cuda:0'),
#  tensor([[0.0518, 0.4681, 0.6738],
#          [0.3315, 0.7837, 0.5631]], device='cuda:0'))

# %% [markdown]
# ### 7. 对第 6 题创建的张量执行矩阵乘法（同样，你可能需要调整其中一个张量的形状）。
#
# 输出应类似：
# ```
# (tensor([[0.3647, 0.4709],
#          [0.5184, 0.5617]], device='cuda:0'), torch.Size([2, 2]))
# ```

# %%
# 对 tensor_A 和 tensor_B 执行矩阵乘法
# tensor_C = torch.matmul(tensor_A, tensor_B) # 形状不匹配会报错
tensor_C = torch.matmul(tensor_A, tensor_B.T)
tensor_C, tensor_C.shape
# Out:
# (tensor([[0.3647, 0.4709],
#          [0.5184, 0.5617]], device='cuda:0'), torch.Size([2, 2]))

# %% [markdown]
# ### 8. 找出第 7 题输出的最大值和最小值。

# %%
# 找最大值
max = torch.max(tensor_C)

# 找最小值
min = torch.min(tensor_C)
max, min
# Out:
# (tensor(0.5617, device='cuda:0'), tensor(0.3647, device='cuda:0'))

# %% [markdown]
# ### 9. 找出第 7 题输出中最大值和最小值对应的索引。

# %%
# 找最大值索引
arg_max = torch.argmax(tensor_C)

# 找最小值索引
arg_min = torch.argmin(tensor_C)
arg_max, arg_min
# Out:
# (tensor(3, device='cuda:0'), tensor(0, device='cuda:0'))

# %% [markdown]
# ### 10. 创建一个形状为 `(1, 1, 1, 10)` 的随机张量，然后去掉所有值为 `1` 的维度，得到形状 `(10)` 的新张量。创建时将种子设为 `7`，并打印第一个张量及其形状，以及第二个张量及其形状。
#
# 输出应类似：
#
# ```
# tensor([[[[0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297,
#            0.3653, 0.8513]]]]) torch.Size([1, 1, 1, 10])
# tensor([0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297, 0.3653,
#         0.8513]) torch.Size([10])
# ```

# %%
# 设置随机种子
torch.manual_seed(7)

# 创建随机张量
tensor_D = torch.rand(size=(1, 1, 1, 10))

# 去掉长度为 1 的维度
tensor_E = tensor_D.squeeze()

# 打印张量
print(tensor_D, tensor_D.shape)
print(tensor_E, tensor_E.shape)
# Out:
# tensor([[[[0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297,
#            0.3653, 0.8513]]]]) torch.Size([1, 1, 1, 10])
# tensor([0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297, 0.3653,
#         0.8513]) torch.Size([10])
