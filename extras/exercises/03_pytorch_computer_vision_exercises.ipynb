# %% [markdown]
# <a href="https://colab.research.google.com/github/mrdbourke/pytorch-deep-learning/blob/main/extras/exercises/03_pytorch_computer_vision_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 03. PyTorch 计算机视觉练习
#
# 下面是一组基于 PyTorch 计算机视觉基础的练习。
#
# 这些练习会很有趣。
#
# 你将会写到大量代码。
#
# ## 资源
#
# 1. 这些练习基于 [Learn PyTorch for Deep Learning 的 notebook 03](https://www.learnpytorch.io/03_pytorch_computer_vision/)。
# 2. 可观看 YouTube 上的[完整解题实战（含报错与调试过程）](https://youtu.be/_PibmqpEyhA)。
#   * **注意：** 我完成这套练习用了大约 3 小时，你可以按这个量级安排时间。
# 3. 更多解答见课程 GitHub 的 [solutions 目录](https://github.com/mrdbourke/pytorch-deep-learning/tree/main/extras/solutions)。

# %%
# 检查 GPU
# !nvidia-smi
# Out:
# Sat Apr 16 03:23:02 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# 导入 torch
import torch

# 练习需要 PyTorch > 1.10.0
print(torch.__version__)

# TODO: 设置设备无关代码
# Out:
# 1.10.0+cu111
# 'cuda'

# %% [markdown]
# ## 1. 当前工业界有哪些场景在使用计算机视觉？请写出 3 个。

# %% [markdown]
# ## 2. 搜索“what is overfitting in machine learning”，并用一句话总结你找到的定义。

# %% [markdown]
# ## 3. 搜索“ways to prevent overfitting in machine learning”，写下你找到的 3 种方法，并为每种方法写一句说明。
# > **注意：** 方法很多，不必一次覆盖全部，先选 3 个开始即可。

# %% [markdown]
# ## 4. 花 20 分钟阅读并点击体验 [CNN Explainer 网站](https://poloclub.github.io/cnn-explainer/)。
#
# * 用网站上的“upload”按钮上传你自己的示例图片，观察图片通过 CNN 各层时会发生什么。

# %% [markdown]
# ## 5. 加载 [`torchvision.datasets.MNIST()`](https://pytorch.org/vision/stable/generated/torchvision.datasets.MNIST.html#torchvision.datasets.MNIST) 的训练集与测试集。

# %% [markdown]
# ## 6. 可视化 MNIST 训练集里至少 5 个不同样本。

# %% [markdown]
# ## 7. 使用 `torch.utils.data.DataLoader` 将 MNIST 训练集和测试集转换为 dataloader，并设置 `batch_size=32`。

# %% [markdown]
# ## 8. 复现 notebook 03 中使用的 `model_2`（与 [CNN Explainer 网站](https://poloclub.github.io/cnn-explainer/)中的模型相同，也称 TinyVGG），并让它能拟合 MNIST 数据集。

# %% [markdown]
# ## 9. 训练你在练习 8 中构建的模型：分别在 CPU 和 GPU 上训练 5 个 epoch，并比较各自耗时。

# %% [markdown]
# ## 10. 使用你训练好的模型进行预测，并至少可视化 5 个样本，对比预测标签与真实标签。

# %% [markdown]
# ## 11. 绘制混淆矩阵，对比模型预测结果与真实标签。

# %% [markdown]
# ## 12. 创建一个形状为 `[1, 3, 64, 64]` 的随机张量，并将其传入 `nn.Conv2d()` 层（超参数可自行设置）。当 `kernel_size` 变大或变小时，你观察到了什么？

# %% [markdown]
# ## 13. 使用与 notebook 03 中训练好的 `model_2` 类似的模型，在测试集 [`torchvision.datasets.FashionMNIST`](https://pytorch.org/vision/main/generated/torchvision.datasets.FashionMNIST.html) 上进行预测。
# * 然后绘制一些模型预测错误的样本，并同时标出图像应有的真实标签。
# * 观察这些错误预测后，你认为更偏向于模型问题还是数据问题？
# * 也就是说，是模型还能继续提升，还是数据标签本身过于相近（例如 "Shirt" 与 "T-shirt/top"）导致难以区分？
