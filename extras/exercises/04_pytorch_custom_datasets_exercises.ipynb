# %% [markdown]
# <a href="https://colab.research.google.com/github/mrdbourke/pytorch-deep-learning/blob/main/extras/exercises/04_pytorch_custom_datasets_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="在 Colab 中打开"/></a>

# %% [markdown]
# # 04. PyTorch 自定义数据集练习模板
#
# 欢迎来到 04 章 PyTorch 自定义数据集练习模板。
#
# 练习 PyTorch 的最好方式，就是写更多 PyTorch 代码。
#
# 请先阅读原始 notebook，然后在需要的地方动手完成练习。
#
# 你可以随时参考原始资源，但建议尽量自己亲手写完所有代码。
#
# ## 资源
#
# 1. 这些练习/解答基于 [Learn PyTorch for Deep Learning 的 notebook 04](https://www.learnpytorch.io/04_pytorch_custom_datasets/)。
# 2. 可观看 YouTube 上的[完整解题实战（含报错与调试过程）](https://youtu.be/vsFMF9wqWx0)。
# 3. 更多解答见课程 GitHub 的 [solutions 目录](https://github.com/mrdbourke/pytorch-deep-learning/tree/main/extras/solutions)。

# %%
# 检查 GPU
# !nvidia-smi
# Out:
# Mon Apr 18 22:14:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# 导入 torch
import torch
from torch import nn

# 练习需要 PyTorch > 1.10.0
print(torch.__version__)

# 设置设备无关代码
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 1.10.0+cu111
# 'cuda'

# %% [markdown]
# ## 1. 我们的模型表现不佳（对数据拟合不充分）。请写出 3 种防止欠拟合的方法，并各用一句话解释。

# %% [markdown]
# ## 2. 复现 [notebook 04 第 1、2、3、4 节](https://www.learnpytorch.io/04_pytorch_custom_datasets/)中的数据加载函数。你最终应得到可直接使用的训练与测试 `DataLoader`。

# %%
# 1. 获取数据

# %%
# 2. 熟悉数据
import os
def walk_through_dir(dir_path):
  """遍历 dir_path 并返回其内容的文件数量。"""
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
# 设置训练与测试路径

# %%
# 可视化一张图像

# %%
# 使用 matplotlib 进行图像可视化

# %% [markdown]
# 我们现在已经在文件夹里拿到了图像数据。
#
# 接下来需要让它们兼容 PyTorch，步骤如下：
# 1. 将数据转换为张量。
# 2. 把张量数据封装为 `torch.utils.data.Dataset`，再进一步转为 `torch.utils.data.DataLoader`。

# %%
# 3.1 使用 torchvision.transforms 转换数据

# %%
# 编写将图像转换为张量的 transform

# %%
# 编写一个函数，用于绘制转换后的图像

# %% [markdown]
# ### 使用 `ImageFolder` 加载图像数据

# %%
# 使用 ImageFolder 创建数据集

# %%
# 以列表形式获取类别名
class_names = train_data.classes
class_names
# Out:
# ['pizza', 'steak', 'sushi']

# %%
# 也可以以字典形式获取类别名
class_dict = train_data.class_to_idx
class_dict
# Out:
# {'pizza': 0, 'steak': 1, 'sushi': 2}

# %%
# 检查每个数据集的长度
len(train_data), len(test_data)
# Out:
# (225, 75)

# %%
# 将训练集和测试集 Dataset 转为 DataLoader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7fce57ec08d0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7fce57ec0dd0>)

# %%
# 我们的 data loader 里一共有多少个图像批次？
# Out:
# (225, 75)

# %% [markdown]
# ## 3. 复现 notebook 04 第 7 节中构建的 `model_0`。

# %% [markdown]
# ## 4. 为 `model_0` 创建训练与测试函数。

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
  
  # 将模型设为训练模式
  model.train()

  # 初始化训练损失与训练准确率
  train_loss, train_acc = 0, 0

  # 遍历 DataLoader 及其批次数据
 
    # 将数据发送到目标设备

    # 1. Forward pass
    
    # 2. Calculate and accumulate loss
    

    # 3. Optimizer zero grad 
    

    # 4. Loss backward 
    

    # 5. Optimizer step
    

    # 计算并累积所有批次的准确率指标
   

  # 计算每个批次的平均损失与平均准确率

# %%
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
  
  # 将模型设为评估模式
  model.eval()

  # 初始化测试损失与测试准确率
  test_loss, test_acc = 0, 0

  # 开启推理上下文管理器
  
    # 遍历 DataLoader 批次
    
      # 将数据发送到目标设备
      

      # 1. Forward pass
      

      # 2. Calculuate and accumulate loss


      # 计算并累积准确率

    
  # 计算每个批次的平均损失与平均准确率

# %%
from tqdm.auto import tqdm

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):
  
  # 创建结果字典
  results = {"train_loss": [],
             "train_acc": [],
             "test_loss": [],
             "test_acc": []}

  # 在多个 epoch 中循环执行训练与测试步骤
  for epoch in tqdm(range(epochs)):
    # 训练步骤
    train_loss, train_acc = train_step(model=model, 
                                       dataloader=train_dataloader,
                                       loss_fn=loss_fn,
                                       optimizer=optimizer)
    # 测试步骤
    test_loss, test_acc = test_step(model=model, 
                                    dataloader=test_dataloader,
                                    loss_fn=loss_fn)
    
    # 打印当前训练进度
    print(f"Epoch: {epoch+1} | "
          f"train_loss: {train_loss:.4f} | "
          f"train_acc: {train_acc:.4f} | "
          f"test_loss: {test_loss:.4f} | "
          f"test_acc: {test_acc:.4f}"
    )

    # 更新结果字典
    results["train_loss"].append(train_loss)
    results["train_acc"].append(train_acc)
    results["test_loss"].append(test_loss)
    results["test_acc"].append(test_acc)

  # 返回结果字典
  return results

# %% [markdown]
# ## 5. 分别将你在练习 3 中构建的模型训练 5、20、50 个 epoch，观察结果变化。
# * 优化器使用 `torch.optim.Adam()`，学习率设为 0.001。

# %%
# 训练 5 个 epoch
torch.manual_seed(42)
torch.cuda.manual_seed(42)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(#TODO, 
                             lr=0.001)

# %%
# 训练 20 个 epoch
torch.manual_seed(42)
torch.cuda.manual_seed(42)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(#TODO, 
                             lr=0.001)

# %%
# 训练 50 个 epoch
torch.manual_seed(42)
torch.cuda.manual_seed(42)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(#TODO, 
                             lr=0.001)

# %% [markdown]
# 看起来模型在后期开始出现过拟合（训练集表现明显好于测试集）。
#
# 要改进这一点，需要引入防止过拟合的方法。

# %% [markdown]
# ## 6. 将模型中的隐藏单元数翻倍，并训练 20 个 epoch，结果会发生什么变化？

# %%
# 将隐藏单元数翻倍并训练 20 个 epoch
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %% [markdown]
# 看起来即使调整了隐藏单元数，模型仍然存在过拟合。
#
# 要解决这个问题，还需要进一步引入抑制过拟合的策略。

# %% [markdown]
# ## 7. 在第 6 步模型基础上把数据量翻倍，再训练 20 个 epoch，结果会发生什么变化？
# * **注意：** 你可以用 [custom data creation notebook](https://github.com/mrdbourke/pytorch-deep-learning/blob/main/extras/04_custom_data_creation.ipynb) 来扩展 Food101 数据集。
# * 也可以直接使用 GitHub 上[已经整理好的双倍数据（20% 子集而非 10%）](https://github.com/mrdbourke/pytorch-deep-learning/blob/main/data/pizza_steak_sushi_20_percent.zip)，你需要像练习 2 一样编写下载代码并接入当前 notebook。

# %%
# 从 GitHub 下载 Pizza/Steak/Sushi 20% 数据
import requests
import zipfile
from pathlib import Path

# 设置数据目录路径
data_path = Path("data/")
image_path = data_path / "pizza_steak_sushi_20_percent"

# 如果图像目录不存在，则下载并准备数据
if image_path.is_dir():
    print(f"{image_path} directory exists.")
else:
    print(f"Did not find {image_path} directory, creating one...")
    image_path.mkdir(parents=True, exist_ok=True)
    
# 下载 pizza、steak、sushi 数据
with open(data_path / "pizza_steak_sushi_20_percent.zip", "wb") as f:
    request = requests.get("https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi_20_percent.zip")
    print("Downloading pizza, steak, sushi 20% data...")
    f.write(request.content)

# 解压 pizza、steak、sushi 数据
with zipfile.ZipFile(data_path / "pizza_steak_sushi_20_percent.zip", "r") as zip_ref:
    print("Unzipping pizza, steak, sushi 20% data...") 
    zip_ref.extractall(image_path)

# %%
# 查看图像数量
walk_through_dir(image_path)

# %% [markdown]
# 很好，我们现在的训练与测试图像都翻倍了。

# %%
# 创建训练和测试路径
train_data_20_percent_path = image_path / "train"
test_data_20_percent_path = image_path / "test"

train_data_20_percent_path, test_data_20_percent_path

# %%
# 将 20% 数据路径转换为 Dataset 和 DataLoader
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch.utils.data import DataLoader

simple_transform = transforms.Compose([
  transforms.Resize((64, 64)),                                     
  transforms.ToTensor()
])

# 创建数据集


# 创建 dataloader

# %%
# 使用增加后的数据量训练模型
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %% [markdown]
# ## 8. 使用你在练习 7 中训练好的模型，对一张自定义 pizza/steak/sushi 图片（也可以从网上下载）进行预测，并分享结果。
# * 你在练习 7 中训练的模型预测正确了吗？
# * 如果没有，你认为可以如何改进？
